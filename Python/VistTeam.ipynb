# %% [markdown]
# <a href="https://colab.research.google.com/github/sholikun32/vistTeam/blob/main/Python/VistTeam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PAKAI RESYS**
# ***(Pantauan Artificial Intelligence Untuk Kesehatan Respiratory System)***
#
#
#
#
#
# *   ## **Metode Artificial Intelligence Project Cycle**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Problem Scoping**
#
# **Latar Belakang:**
#
# Sistem pernapasan manusia adalah esensial untuk kehidupan dan fungsi tubuh yang tepat. Gangguan dalam sistem pernapasan, seperti penyakit paru-paru, TB, asma, infeksi pernapasan, dan pandemik seperti COVID-19, dapat berdampak serius pada kesehatan dan kualitas hidup individu. Teknologi kecerdasan buatan (AI) telah membuka peluang baru dalam perawatan kesehatan, terutama dalam pemantauan dan analisis kesehatan pernapasan.
#
# **Masalah:**
#
# Meningkatnya jumlah individu dengan penyakit pernapasan kronis memerlukan solusi pemantauan berkelanjutan yang akurat. Saat ini, teknologi AI belum sepenuhnya dimanfaatkan untuk pengawasan kesehatan pernapasan, menyebabkan potensi yang belum dimaksimalkan dalam pendeteksian dini penyakit, analisis data cepat dan akurat, serta prediksi perkembangan penyakit.
#
# **Tujuan:**
#
# Tujuan proyek ini adalah mengembangkan RESYS (Pantauan Artificial Intelligence untuk Kesehatan Respiratory System), sebuah sistem yang menggunakan AI untuk pemantauan kesehatan pernapasan. Sistem ini akan mampu mendeteksi dini penyakit pernapasan, menganalisis data secara cepat dan akurat, melakukan pemantauan berkelanjutan, dan meramalkan perkembangan penyakit. Melalui pengembangan algoritma yang canggih, pengumpulan data yang lebih baik, dan integrasi sistem yang kuat, proyek ini bertujuan meningkatkan perawatan dan pemahaman tentang kondisi pernapasan.
#
# **Manfaat**
# Manfaat yang diberikan dari sistem PAKAI RESYS ini antara lain, dapat mendeteksi gejala awal penyakit pernapasan yang memungkinkan intervensi medis yang lebih cepat dan efektif. Sistem juga dapat memberikan diagnosa yang lebih akurat berdasarkan analisi mendalam dari data pernapasan yang dapat membantu dokter dalam membuat keputusan yang tepat.
# Dengan sistem ini juga memungkinkan pengguna dapat memantau kesehatan pernapasan dalam kehidupan sehari-hari, memberikan kemandirian dalam manajemen penyakit mereka.
#
# **Fitur**
#
#  Fitur utama yang diberikan dari sistem PAKAI RESYS ini antara lain:
#
#
# 1.   Pemetaan penyebaran penyakit terkait sistem pernapasan.
# 2.   Tabel data untuk kasus yang berhubungan dengan penyakit sistem pernapasan.
# 3.   Chat bot yang bisa digunakan untuk tanya jawab yang berkaitan dengan sistem pernapasan.
#
# **Use Case**

# %% [markdown]
# Sistem yang kami rancang memiliki tiga skenario penggunaan utama, yang melibatkan tiga aktor berbeda, yaitu guest (pengunjung), admin (administrator), dan chatbot. Masing-masing aktor memiliki peran dan fungsionalitas yang khusus dalam ekosistem sistem kami. Sebagai pengunjung (guest), pengguna akan dapat menjelajahi berbagai fitur yang disediakan oleh sistem kami. Sebagai administrator (admin), pengguna akan memiliki akses dan kendali penuh terhadap manajemen dan pengaturan sistem. Sedangkan chatbot akan bertindak sebagai entitas yang mampu memberikan respons dan bantuan kepada pengguna dalam bentuk interaksi berbasis teks. Integrasi antara ketiga aktor ini akan memberikan pengalaman pengguna yang komprehensif dan beragam dalam penggunaan sistem kami.

# %% [markdown]
# ![use_case_comfest-Halaman-1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Desain Sistem**
#
# wireframe sistem yang telah kami rancang, terdiri dari tiga halaman utama, yakni halaman beranda (home), chatbot, dan halaman pertanyaan umum (FAQ). Wireframe ini mencerminkan desain awal dari sistem kami, dengan penekanan pada tata letak dan struktur yang akan membentuk pengalaman pengguna yang optimal di setiap halaman. Halaman home dirancang untuk memberikan gambaran menyeluruh tentang fitur apa saja sistem, sementara halaman chatbot akan menjadi pusat interaksi pengguna dengan kecerdasan buatan. Terakhir, halaman FAQ akan memberikan jawaban atas pertanyaan umum yang mungkin timbul dalam benak pengguna.

# %% [markdown]
# # **Data Aquastion**
#
# **Metode pengumpulan data**
#
# Mengumpulkan data  dari BPJS terkait kasus Pernafasan

# %% [markdown]
# ## **Import Library**

# %%
import uuid
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from IPython.display import Markdown, display
warnings.filterwarnings("ignore")
from datetime import datetime, timedelta

# import all libraries and dependencies for data visualization
pd.options.display.float_format='{:.4f}'.format
plt.rcParams['figure.figsize'] = [8,8]
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 1)
sns.set(style='darkgrid')
import matplotlib.ticker as plticker
# %matplotlib inline

# import all libraries and dependencies for machine learning
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import IncrementalPCA
from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
from math import isnan

# import all libraries and dependencies for clustering
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import explained_variance_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, MaxAbsScaler, Binarizer
from sklearn.model_selection import LearningCurveDisplay, ShuffleSplit
# from sklearn.preprocessing import

from yellowbrick.cluster import KElbowVisualizer

# %% [markdown]
# ## **Unduh Dataset**
#
# Unduh Dataset dari Google Drive menggunakan !gdown dengan memberikan ID tautan Google Drive untuk setiap file

# %%
# !gdown --id 1KJqM44OqZonDUaD5Jgdz-54C1-iLZmMs -O dataset_bpjs.xlsx
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1KJqM44OqZonDUaD5Jgdz-54C1-iLZmMs
# To: /content/dataset_bpjs.xlsx
# 100% 273M/273M [00:05<00:00, 46.4MB/s]

# %% [markdown]
# ## **Load Dataset**

# %%
import pandas as pd
data_pasien = pd.read_excel('/content/dataset_bpjs.xlsx')
# Menampilkan  dataframe
data_pasien.head()
# Out:
#    Nomor peserta  Nomor keluarga    Bobot No Asal Rujukan (ID Kunjungan FKTP)  \
# 0  455297864      354398080      10.2738   NaN
# 1  428331611      355534480      248.6777  NaN
# 2  159537057      159537057      36.8733   NaN
# 3  87132631       98569517       92.2359   NaN
# 4  25031617       14211084       78.5791   NaN
#
#        ID Kunjungan Tanggal datang kunjungan FKRTL  \
# 0  134540221V000105 2021-02-26
# 1  459250521V000580 2021-05-31
# 2  242680121V000408 2021-01-04
# 3  112271221V002764 2021-12-20
# 4  321561121V004514 2021-11-21
#
#   Tanggal pulang kunjungan FKRTL              Provinsi FKRTL  \
# 0 2021-02-28                      DAERAH ISTIMEWA YOGYAKARTA
# 1 2021-06-02                      JAWA TIMUR
# 2 2021-01-07                      ACEH
# 3 2021-12-25                      JAWA TENGAH
# 4 2021-11-25                      JAWA BARAT
#
#   Kabupaten/Kota FKRTL Kepemilikan FKRTL  Jenis FKRTL  \
# 0  KOTA YOGYAKARTA      Swasta            Rumah sakit
# ...

# %% [markdown]
# ## **Informasi Dataset**

# %% [markdown]
# *Check the data information using data_pasien.info()*

# %%
data_pasien.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872201 entries, 0 to 872200
# Data columns (total 55 columns):
#  #   Column                                                           Non-Null Count   Dtype
# ---  ------                                                           --------------   -----
#  0   Nomor peserta                                                    872201 non-null  int64
#  1   Nomor keluarga                                                   872201 non-null  int64
#  2   Bobot                                                            872201 non-null  float64
#  3   No Asal Rujukan (ID Kunjungan FKTP)                              519692 non-null  object
#  4   ID Kunjungan                                                     872201 non-null  object
#  5   Tanggal datang kunjungan FKRTL                                   872201 non-null  datetime64[ns]
#  6   Tanggal pulang kunjungan FKRTL                                   872201 non-null  datetime64[ns]
# ...

# %% [markdown]
# ## **Descriptive structure of the data using data_pasien.describe()**

# %%
data_pasien.describe()
# Out:
#        Nomor peserta  Nomor keluarga       Bobot  \
# count 872201.0000    872201.0000     872201.0000
# mean  140733245.9372 140416730.1580  79.5153
# std   133135074.3614 129040379.3164  170.8024
# min   1144.0000      2147.0000       0.5050
# 25%   41290743.0000  43474476.0000   10.4002
# 50%   83575458.0000  87447691.0000   33.8268
# 75%   223666771.0000 215916866.0000  90.3449
# max   460553791.0000 460524668.0000  18235.5586
#
#        INACBGs - Spesifikasi kelompok kasus (Digit ke-3)  Group Tarif INACBGs  \
# count 872201.0000                                        872201.0000
# mean  30.8075                                            837228.2183
# std   14.1355                                            2614295.3846
# min   1.0000                                             68200.0000
# 25%   16.0000                                            184900.0000
# 50%   42.0000                                            192200.0000
# ...

# %% [markdown]
# *Fungsi describe()  digunakan untuk menghasilkan ringkasan statistik deskriptif dari data numerik dalam sebuah DataFrame atau objek Series. Ini akan memberikan wawasan awal tentang distribusi data dan beberapa statistik penting seperti rata-rata, median, kuartil,*

# %% [markdown]
# ## **Check the categorical and numerical columns**

# %%
# Memisahkan kolom kategorikal dan numerikal
categorical_columns_data_pasien = data_pasien.select_dtypes(include=['object', 'category']).columns
numerical_columns_data_pasien = data_pasien.select_dtypes(include=['int64', 'float64']).columns

# Menampilkan hasil
print("Kolom Kategorikal:")
print(categorical_columns_data_pasien)
print("\nKolom Numerikal:")
print(numerical_columns_data_pasien)
# Out:
# Kolom Kategorikal:
# Index(['No Asal Rujukan (ID Kunjungan FKTP)', 'ID Kunjungan', 'Provinsi FKRTL',
#        'Kabupaten/Kota FKRTL', 'Kepemilikan FKRTL', 'Jenis FKRTL',
#        'Tipe FKRTL', 'Tingkat Pelayanan FKRTL', 'Jenis Poli FKRTL',
#        'Segmen Peserta saat akses layanan FKRTL',
#        'Kelas rawat saat peserta mengakses pelayanan kesehatan di FKRTL',
#        'Status pulang dari FKRTL',
#        'Kode dan nama diagnosis masuk ICD 10 (3 digit)',
#        'Kode diagnosis masuk ICD 10 (3 digit)',
#        'Kode ICD 10 diagnosis masuk FKRTL (3-6digit)',
#        'Nama diagnosis masuk FKRTL (3-6digit)',
#        'Kode dan nama diagnosis primer ICD 10 (3 digit)',
#        'Kode diagnosis primer ICD 10 (3 digit)',
#        'Kode ICD 10 diagnosis primer FKRTL (3-6digit)',
#        'Nama diagnosis primer FKRTL (3-6digit)', 'Kode INACBGs',
#        'Deskripsi kode INACBGs',
#        'INACBGs - Kode Casemix main groups (Digit ke-1)',
# ...

# %% [markdown]
# Melakukan pemeriksaan terhadap kolom kategorikal dan numerik dalam data adalah penting karena:
#
# *   Memahami Jenis Data: Mengidentifikasi apakah data adalah kategorikal atau numerik.
#
# *   Preprocessing Data: Memungkinkan persiapan data, seperti encoding, penanganan nilai hilang, dan penanganan outlier.
#
# *   Analisis dan Visualisasi Data: Memahami distribusi dan tren data menggunakan visualisasi yang sesuai.
#
# *   Persiapan untuk Model Machine Learning: Memastikan data siap digunakan dalam model ML dengan preprocessing yang sesuai.
#
# *   Meningkatkan Pemahaman Data: Menyelidiki pola, hubungan, atau tren yang dapat mengarah ke wawasan yang lebih dalam. *italicized text*

# %% [markdown]
# ## **Check the total number of unique values in the Categorical columns**

# %%
# Calculate the total number of unique values in each categorical column
unique_counts = data_pasien[categorical_columns_data_pasien].nunique()

# Display the results
print("Total number of unique values in each categorical column:")
print(unique_counts)
# Out:
# Total number of unique values in each categorical column:
# No Asal Rujukan (ID Kunjungan FKTP)                                191090
# ID Kunjungan                                                       872201
# Provinsi FKRTL                                                     34
# Kabupaten/Kota FKRTL                                               488
# Kepemilikan FKRTL                                                  9
# Jenis FKRTL                                                        2
# Tipe FKRTL                                                         24
# Tingkat Pelayanan FKRTL                                            2
# Jenis Poli FKRTL                                                   42
# Segmen Peserta saat akses layanan FKRTL                            5
# Kelas rawat saat peserta mengakses pelayanan kesehatan di FKRTL    3
# Status pulang dari FKRTL                                           5
# ...

# %% [markdown]
# Memeriksa jumlah total nilai unik (unique values) dalam kolom kategorikal (categorical columns) adalah langkah penting dalam analisis data, dan hal ini memiliki beberapa alasan penting:
#
# *   Memahami Variabilitas Data:  Dengan menghitung jumlah nilai unik dalam kolom kategorikal, Anda dapat mengukur tingkat variasi atau keragaman dalam data. Jika sebuah kolom hanya memiliki beberapa nilai unik, mungkin tidak banyak variasi dalam data tersebut. Di sisi lain, jika ada banyak nilai unik, ini menunjukkan variasi yang lebih besar dalam kategori tersebut.
#
# *   Mengetahui Kompleksitas Data: Informasi tentang jumlah nilai unik juga membantu Anda memahami kompleksitas dataset. Data dengan banyak nilai unik mungkin lebih sulit untuk dianalisis dan memerlukan strategi pemrosesan yang berbeda dibandingkan dengan data yang memiliki sedikit nilai unik.
#
# *   Pemilihan Fitur: Saat membangun model pembelajaran mesin atau melakukan analisis data, Anda mungkin perlu memilih fitur-fitur (kolom-kolom) yang akan digunakan. Jumlah nilai unik dalam kolom kategorikal dapat membantu Anda memutuskan apakah kolom tersebut cocok untuk digunakan sebagai fitur atau apakah perlu dilakukan pengolahan lebih lanjut, seperti penggantian dengan fitur yang lebih relevan atau menggabungkan beberapa kategori.
#
# *   Identifikasi Masalah Data: Jumlah nilai unik juga dapat membantu Anda mengidentifikasi masalah dalam data, seperti data yang terduplikat atau masalah dengan pengumpulan data. Jika ada jumlah nilai unik yang tidak sesuai dengan yang diharapkan, ini bisa menjadi petunjuk bahwa ada masalah dalam data tersebut.
#
# *   Optimasi Pengolahan Data: Dalam proses preprocessing data, seperti encoding kategori atau penanganan nilai yang hilang, informasi tentang jumlah nilai unik dapat membantu Anda memilih metode yang paling cocok. Misalnya, jika jumlah nilai unik sangat besar, Anda mungkin perlu mempertimbangkan teknik encoding kategori yang lebih efisien

# %% [markdown]
# # **Data Preprocessing**

# %%
#Isnull Value info
def missing_value_table(df):
    missing_value = df.isna().sum().sort_values(ascending=False)
    missing_value_percent = 100 * df.isna().sum()//len(df)
    missing_value_table = pd.concat([missing_value, missing_value_percent], axis=1)
    missing_value_table_return = missing_value_table.rename(columns = {0 : 'Missing Values', 1 : '% Value'})
    cm = sns.light_palette("red", as_cmap=True)
    missing_value_table_return = missing_value_table_return.style.background_gradient(cmap=cm)
    return missing_value_table_return

def printmd(string):
    display(Markdown(string))

def info_table(title, dataframe):
    d = {
        'Column':[],
        'Non-Null Count':[],
        'Dtype':[],
    }
    df = pd.DataFrame(data=d)
    cols = []
    counts = []
    dtypes = []
    for col in list(dataframe.columns):
        cols.append(col)
        counts.append("{} non-null".format(dataframe[col].count()))
        dtypes.append(dataframe[col].dtype)
    printmd("**{}**".format(title))
    printmd("RangeIndex: **{}** entries, **0** to **{}**".format(len(dataframe.index), len(dataframe.index)-1 ))
    printmd("Data columns (total **{}** columns):".format(len(dataframe.columns)))
    df['Column'] = cols
    df['Non-Null Count'] = counts
    df['Dtype'] = dtypes
    cm = sns.light_palette("red", as_cmap=True)
    df = df.style.background_gradient(cmap=cm)
    with pd.option_context('display.max_rows', None,):
        return df

# Calculating Hopkins score to know whether the data is good for clustering or not.

def hopkins(X):
    d = X.shape[1]
    n = len(X)
    m = int(0.1 * n)
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)

    rand_X = sample(range(0, n, 1), m)

    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])

    HS = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(HS):
        print(ujd, wjd)
        HS = 0

    return HS

def highlight_cell(col, col_label, row_label):
    mask = (col.index == row_label)
    return ["background-color: #FFBB33" if val_bool else "" for val_bool in mask]

# %% [markdown]
# **(Collected Data)/"Pengumpulan data Penyakit Pernafasan J00-J99"**

# %%
import pandas as pd
# Membuat DataFrame baru 'data_pernafasan' dengan baris yang memenuhi kriteria
data_pernafasan = data_pasien[data_pasien['Kode diagnosis masuk ICD 10 (3 digit)'].str.match(r'J[0-9]{2}')]
# Menampilkan DataFrame 'data_pernafasan'
data_pernafasan
# Out:
#         Nomor peserta  Nomor keluarga    Bobot  \
# 135     75959953       7847033        22.7963
# 374     41823012       42618516       1.9702
# 474     429642868      310666976      1.8328
# 478     69576776       50083113       83.9368
# 530     457789238      457789238      8.9523
# ...           ...            ...         ...
# 861658  63780332       55690971       10.5052
# 861737  31537570       27561428       211.5753
# 861884  389212200      389212200      61.8979
# 861985  94696355       83338366       67.0233
# 862179  8133336        115987068      105.6826
#
#        No Asal Rujukan (ID Kunjungan FKTP)      ID Kunjungan  \
# 135     NaN                                 415410721V000269
# 374     NaN                                 308550421V000180
# 474     NaN                                 462570721V000356
# 478     NaN                                 236921021V002360
# 530     NaN                                 393501221V000106
# ...

# %%
# Simpan DataFrame yang telah difilter ke file Excel
excel_filename = "data_pernafasan.xlsx"
data_pernafasan.to_excel(excel_filename, index=False)

# %% [markdown]
# ## **Check Missing Value**

# %%
missing_value_table(data_pernafasan)
# Out:
# <style type="text/css">
# #T_04b1c_row0_col0, #T_04b1c_row0_col1, #T_04b1c_row1_col0, #T_04b1c_row2_col0, #T_04b1c_row3_col0 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_04b1c_row1_col1, #T_04b1c_row2_col1, #T_04b1c_row3_col1, #T_04b1c_row4_col1, #T_04b1c_row5_col1, #T_04b1c_row6_col1, #T_04b1c_row7_col1, #T_04b1c_row8_col1 {
#   background-color: #ff0202;
#   color: #f1f1f1;
# }
# #T_04b1c_row4_col0, #T_04b1c_row5_col0, #T_04b1c_row6_col0, #T_04b1c_row7_col0, #T_04b1c_row8_col0 {
#   background-color: #ff0101;
#   color: #f1f1f1;
# }
# #T_04b1c_row9_col0 {
#   background-color: #fa5a5a;
#   color: #f1f1f1;
# }
# #T_04b1c_row9_col1 {
#   background-color: #fa5b5b;
#   color: #f1f1f1;
# }
# #T_04b1c_row10_col0 {
#   background-color: #f79897;
#   color: #000000;
# }
# #T_04b1c_row10_col1 {
#   background-color: #f79999;
#   color: #000000;
# }
# ...

# %%
# Menghapus kolom dengan nilai yang hilang
data_pernafasan = data_pernafasan.dropna(axis=1)
missing_value_table(data_pernafasan)
# Out:
# <style type="text/css">
# ...

# %%
data_pernafasan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28532 entries, 135 to 862179
# Data columns (total 44 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Nomor peserta                                                    28532 non-null  int64
#  1   Nomor keluarga                                                   28532 non-null  int64
#  2   Bobot                                                            28532 non-null  float64
#  3   ID Kunjungan                                                     28532 non-null  object
#  4   Tanggal datang kunjungan FKRTL                                   28532 non-null  datetime64[ns]
#  5   Tanggal pulang kunjungan FKRTL                                   28532 non-null  datetime64[ns]
#  6   Provinsi FKRTL                                                   28532 non-null  object
# ...

# %%
import pandas as pd

# Membuat DataFrame baru
data_pernafasan_new = data_pernafasan[['Tanggal datang kunjungan FKRTL',
              'Tanggal pulang kunjungan FKRTL',
              'Provinsi FKRTL',
              'Kabupaten/Kota FKRTL',
              'Kode diagnosis masuk ICD 10 (3 digit)',
              'Nama diagnosis masuk FKRTL (3-6digit)',
              'Status pulang dari FKRTL']]

# Mengganti nama kolom
data_pernafasan_new.columns = ['Tanggal Datang',
                   'Tanggal Pulang',
                   'Provinsi',
                   'Kabupaten/Kota',
                   'Kode Diagnosis Masuk ICD 10',
                   'Nama Diagnosis Masuk',
                   'Status Pulang']

# Menampilkan dari DataFrame baru
data_pernafasan_new
# Out:
#        Tanggal Datang Tanggal Pulang                    Provinsi  \
# 135    2021-07-20     2021-07-20      SUMATERA SELATAN
# 374    2021-04-09     2021-04-11      SULAWESI SELATAN
# 474    2021-07-14     2021-07-19      SUMATERA SELATAN
# 478    2021-10-22     2021-10-26      BENGKULU
# 530    2021-12-08     2021-12-11      ACEH
# ...           ...            ...       ...
# 861658 2021-03-09     2021-03-09      ACEH
# 861737 2021-03-02     2021-03-02      DAERAH ISTIMEWA YOGYAKARTA
# 861884 2021-01-12     2021-01-12      JAWA TENGAH
# 861985 2021-11-17     2021-11-17      JAWA TENGAH
# 862179 2021-01-04     2021-01-04      ACEH
#
#           Kabupaten/Kota Kode Diagnosis Masuk ICD 10  \
# 135     LAHAT             J22
# 374     KOTA MAKASSAR     J06
# 474     KOTA PALEMBANG    J18
# 478     KOTA BENGKULU     J45
# 530     ACEH BARAT        J12
# ...            ...        ...
# 861658  KOTA LHOKSEUMAWE  J42
# 861737  GUNUNG KIDUL      J44
# 861884  DEMAK             J35
# ...

# %%
# Menyimpan DataFrame ke dalam file Excel
data_pernafasan_new.to_excel('data_pernafasan_new.xlsx', index=False)

# %% [markdown]
# ## **Memeriksa Duplikat**

# %%
duplicates =data_pernafasan[data_pernafasan.duplicated()]
print("Jumlah baris yang duplikat:",len(duplicates))
print("Baris duplikat:")
duplicates.head()
# Out:
# Jumlah baris yang duplikat: 0
# Baris duplikat:
# Empty DataFrame
# ...

# %% [markdown]
# ## **Data Exploration**

# %% [markdown]
# *Explorasi data di lakukan di tableau*

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data Scatter Plot
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.scatter(data_pernafasan_new['Tanggal Datang'], data_pernafasan_new['Tanggal Pulang'], c='b', marker='o')
plt.xlabel('Tanggal Datang')
plt.ylabel('Tanggal Pulang')
plt.title('Scatter Plot')

# Data Histogram
plt.subplot(1, 2, 2)
sns.histplot(data_pernafasan_new['Tanggal Datang'], bins=20, color='g', kde=True)
plt.xlabel('Tanggal Datang')
plt.ylabel('Frekuensi')
plt.title('Histogram')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

provinsi_counts = data_pernafasan_new['Provinsi'].value_counts()
plt.figure(figsize=(12, 6))
plt.bar(provinsi_counts.index, provinsi_counts.values)
plt.xlabel('Provinsi')
plt.ylabel('Jumlah Kunjungan')
plt.title('Jumlah Kunjungan per Provinsi')
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

status_pulang_counts = data_pernafasan_new['Status Pulang'].value_counts()
plt.pie(status_pulang_counts, labels=status_pulang_counts.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Proporsi Status Pulang')
plt.show()

# %% [markdown]
# Modelling Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Membaca data dari file Excel
data = pd.read_excel('data_pernafasan_new.xlsx')

# Memilih kolom yang akan digunakan untuk pemodelan
features = ['Provinsi', 'Kabupaten/Kota', 'Kode Diagnosis Masuk ICD 10']
target = 'Status Pulang'

X = data[features]
y = data[target]

# Melakukan one-hot encoding pada kolom-kolom kategorikal
X_encoded = pd.get_dummies(X, columns=['Provinsi', 'Kabupaten/Kota', 'Kode Diagnosis Masuk ICD 10'])

# Memisahkan data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Membuat dan melatih model RandomForestClassifier
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Membuat prediksi pada data uji
y_pred = model.predict(X_test)

# Menilai kinerja model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(report)
# Out:
# Accuracy: 0.9663571053092693
#               precision    recall  f1-score   support
#
#    Meninggal       0.00      0.00      0.00        41
# Pulang Paksa       0.00      0.00      0.00        23
#        Rujuk       0.00      0.00      0.00        54
#        Sehat       0.97      1.00      0.98      5496
#   Tidak Tahu       0.86      0.46      0.60        93
#
#     accuracy                           0.97      5707
#    macro avg       0.37      0.29      0.32      5707
# weighted avg       0.95      0.97      0.96      5707

# %% [markdown]
# Pada analisis ini, kami menggunakan model RandomForestClassifier untuk melakukan klasifikasi pada dataset. Berikut adalah hasil evaluasi kinerja model:
#
# **Akurasi (Accuracy): 0.9663571053092693**
#
# Model kami mencapai tingkat akurasi sekitar 96.64%, yang berarti sekitar 96.64% dari prediksi yang dibuat oleh model benar.
#
# **Presisi (Precision):**
#
# Meninggal: 0.00
# Pulang Paksa: 0.00
# Rujuk: 0.00
# Sehat: 0.97
# Tidak Tahu: 0.86
# Model kami memiliki tingkat presisi yang tinggi untuk kelas "Sehat" sekitar 97%, yang menunjukkan kemampuannya untuk mengidentifikasi kelas ini dengan baik. Namun, untuk kelas "Meninggal," "Pulang Paksa," dan "Rujuk," presisi sangat rendah.
#
# **Recall (Sensitivitas):**
#
# Meninggal: 0.00
# Pulang Paksa: 0.00
# Rujuk: 0.00
# Sehat: 1.00
# Tidak Tahu: 0.46
# Model memiliki recall yang tinggi (1.00) untuk kelas "Sehat," yang menunjukkan bahwa model mampu mengambil semua instance dari kelas "Sehat." Namun, untuk kelas lainnya, recall sangat rendah.
#
# **F1-Skor (F1-Score):**
#
# Meninggal: 0.00
# Pulang Paksa: 0.00
# Rujuk: 0.00
# Sehat: 0.98
# Tidak Tahu: 0.60
# F1-score adalah harmonik rata-rata dari presisi dan recall. Kembali, model kami mencapai F1-score yang tinggi untuk kelas "Sehat," tetapi sangat rendah untuk kelas lainnya.
#
# **Dukungan (Support):**
#
# Meninggal: 41
# Pulang Paksa: 23
# Rujuk: 54
# Sehat: 5496
# Tidak Tahu: 93
# Dukungan mencerminkan jumlah sampel dalam setiap kelas.
#
# **Kesimpulan:**
#
# *   Model RandomForestClassifier kami memiliki kinerja yang sangat baik dalam mengidentifikasi kelas "Sehat," dengan tingkat presisi, recall, dan F1-score yang tinggi.
# *   Namun, model memiliki masalah yang signifikan dalam mengidentifikasi kelas "Meninggal," "Pulang Paksa," dan "Rujuk," dengan presisi, recall, dan F1-score yang sangat rendah.
